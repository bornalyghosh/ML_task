# %% [markdown]
# ![avg.png](attachment:avg.png)
# Image(url="avg.png", width=300, height=300)

# %% [markdown]
# ![minmaxmedian.png](attachment:minmaxmedian.png)
# Image(url="minmaxmedian.png", width=300, height=300)

# %% [markdown]
# External Referenced Materials links https://matplotlib.org/stable/api/index.html
#
# General Thoughts about the Process:
#
# Data Understanding: Carefully examine your data to understand its structure, identify missing values (nan), and ensure the time column is formatted correctly for plotting.
#
#
# Specific Strategies Explored and Abandoned Approaches:
# Strategy: Using pandas for data manipulation (assuming the data is a CSV file) is often a convenient and efficient approach.
